# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Grace Loisa]
# - **Email:** [6162101065@student.unpar.ac.id]
# - **ID Dicoding:** [Grace Loisa]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# *   Produk mana yang terjual paling banyak dan paling sedikit?
# *  Dari segi lokasi geografis, wilayah mana yang melakukan pembelian terbanyak?
# *   Jenis metode pembayaran apa yang paling umum digunakan oleh customer?
# *   Berdasarkan umpan balik yang diterima, bagaiman tingkat kepuasan customer terhadap layanan yang diberikan?

# %% [markdown]
# ## Import semua library yang dibutuhkan

# %% [markdown]
# Hal pertama yang perlu dilakukan dalam menganalisis data adalah proses import seluruh library yang dibutuhkan agar proses analisis dapat berjalan dengan baik.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
import matplotlib.image as mpimg
import requests
import io
import gdown
import os
import datetime as dt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Data wrangling terdiri dari tiga tahap yaitu gathering data (pengumpulan data), assessing data (menilai data), dan cleaning data (membersihkan data).

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Tahap ini merupakan tahap pengumpulan semua data yang dibutuhkan untuk menjawab semua pertanyaan atau masalah bisnis yang dihadapi

# %% [markdown]
# Memuat tabel customers menjadi DataFrame terlebih dahulu

# %%
customers_df = pd.read_csv("/content/E-commerce/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Memuat tabel orders menjadi DataFrame

# %%
orders_df= pd.read_csv("/content/E-commerce/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# Memuat tabel products dengan DataFrame

# %%
products_df = pd.read_csv("/content/E-commerce/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# Memuat tabel sellers dengan DataFrame

# %%
sellers_df = pd.read_csv("/content/E-commerce/sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# Memuat tabel geolocation dengan DataFrame

# %%
geolocation_df = pd.read_csv("/content/E-commerce/geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# Memuat tabel order items dengan DataFrame

# %%
order_items_df = pd.read_csv("/content/E-commerce/order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# Memuat tabel order payments dengan DataFrame

# %%
order_payments_df = pd.read_csv("/content/E-commerce/order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Memuat tabel order reviews dengan DataFrame

# %%
order_reviews_df = pd.read_csv("/content/E-commerce/order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# Memuat tabel products category dengan DataFrame

# %%
products_category_df = pd.read_csv("/content/E-commerce/product_category_name_translation.csv")
products_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Pada tahap ini akan dilakukan penilaian terhadap data-data tersebut untuk menilai kualitas dan struktur data serta dapat mengidentifikasi berbagai masalah pada data.

# %% [markdown]
# **Menilai data customers_df**

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# cek statistik

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **Menilai data orders_df**

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94496 entries, 0 to 94495
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       94496 non-null  object
#  1   customer_id                    94496 non-null  object
#  2   order_status                   94496 non-null  object
#  3   order_purchase_timestamp       94496 non-null  object
#  4   order_approved_at              94344 non-null  object
#  5   order_delivered_carrier_date   92814 non-null  object
#  6   order_delivered_customer_date  91683 non-null  object
#  7   order_estimated_delivery_date  94495 non-null  object
# dtypes: object(8)
# memory usage: 5.8+ MB

# %% [markdown]
# Terdapat kejanggalan yaitu perbedaan pada jumlah data pada kolom order_approved_at, order_delivered_carrier_date, dan order_delivered_customer_date sehingga akan dilihat jumlah missing valuesnya.

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 152
# order_delivered_carrier_date     1682
# order_delivered_customer_date    2813
# order_estimated_delivery_date       1
# dtype: int64

# %% [markdown]
# Selanjutnya akan dicek apakah terdapat duplikasi data.

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# cek statistik

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              94496                             94496
# unique                             94496                             94496
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         94496                    94496                94344
# unique            8                    93981                86528
# top       delivered      2018-06-01 13:39:44  2018-02-27 04:31:10
# freq          91684                        3                    8
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         92814                         91683
# unique                        77474                         90942
# top             2018-05-09 15:48:00           2017-12-02 00:26:45
# freq                             44                             3
#
#        order_estimated_delivery_date
# count                          94495
# unique                           459
# top              2017-12-20 00:00:00
# freq                             500

# %% [markdown]
# **Menilai data products_df**

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Terdapat kejanggalan yaitu perbedaan pada jumlah data pada kolomnya  sehingga akan dilihat jumlah missing valuesnya.

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Selanjutnya akan dicek apakah ada duplikasi data

# %% [markdown]
# cek statistik

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Menilai data sellers_df**

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Menilai data geolocation_df**

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  261831

# %% [markdown]
# statistik

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Menilai data order_items_df**

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# statistik

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# Menilai data order_payments_df

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# statistik

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# **Menilai data order_reviews_df**

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Terdapat kejanggalan yaitu perbedaan pada jumlah data pada kolom review_comment_title dan review_comment_message sehingga akan dilihat jumlah missing valuesnya.

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Selanjutnya, akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", order_reviews_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# statistik

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# **Menilai data products_category_df**

# %%
products_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Akan dicek apakah terdapat duplikasi data

# %%
print("Jumlah duplikasi: ", products_category_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# statistik

# %%
products_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Tahap ini adalah tahap pembersihan data dari masalah yang ditemukan pada proses assesing data. Tahap ini perlu dilakukan sebelum masuk tahap analis data.

# %% [markdown]
# **Cleaning untuk data tabel geolocation**

# %%
geolocation_df.drop_duplicates(inplace=True)

# %% [markdown]
# Setelah proses penghapusan, akan dicek kembali apakah prosesnya berjalan dengan lancar.

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Cleaning data tabel orders**

# %% [markdown]
# Diawali dengan memeriksa apakah ada nilai NaN dalam kolom-kolom tersebut lalu mengonversi nilai yang tidak bisa diparse menjadi Not a Time. Setelah itu konversikan kolom-kolom tersebut ke dalam type date time.

# %%
orders_columns=[
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]
print(orders_df[orders_columns].isnull().sum())
for col in orders_columns:
    orders_df[col] = pd.to_datetime(orders_df[col], errors='coerce')
# Out:
# order_purchase_timestamp            0
# order_approved_at                 152
# order_delivered_carrier_date     1683
# order_delivered_customer_date    2813
# order_estimated_delivery_date       1
# dtype: int64

# %% [markdown]
# Cek kembali apakah Dtype nya sudah menjadi date time

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94496 entries, 0 to 94495
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       94496 non-null  object
#  1   customer_id                    94496 non-null  object
#  2   order_status                   94496 non-null  object
#  3   order_purchase_timestamp       94496 non-null  datetime64[ns]
#  4   order_approved_at              94344 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   92813 non-null  datetime64[ns]
#  6   order_delivered_customer_date  91683 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  94495 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 5.8+ MB

# %% [markdown]
# **Cleaning untuk data tabel products**

# %% [markdown]
# Cek terlebih dahulu ada kolom apa saja yang ada di tabel products

# %%
print(products_df.columns)
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %% [markdown]
# Dilanjutkan dengan menghapus kolom yang dirasa tidak digunakan dalam proses analisis data.

# %%
product_drop_columns = ['product_name_lenght',
                        'product_description_lenght',
                        'product_weight_g',
                        'product_length_cm',
                        'product_height_cm',
                        'product_width_cm']
products_df.drop(product_drop_columns, axis= 1, inplace= True)

# %% [markdown]
# Lalu isi nilai yang hilang (missing value) yang ditemukan.

# %%
products_df['product_category_name'].fillna(products_df['product_category_name'].mode()[0], inplace=True)
products_df['product_photos_qty'].fillna(products_df['product_photos_qty'].median(), inplace=True)

# %% [markdown]
# Cek kembali apakah datanya sudah bersih

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32951 non-null  object
#  2   product_photos_qty     32951 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 772.4+ KB

# %% [markdown]
# **Cleaning data tabel order_items**

# %% [markdown]
# Konversi kolom yang berisikan tanggal menjadi Dtype date time

# %%
order_item_col=['shipping_limit_date']
for col in order_item_col:
  order_items_df[col]=pd.to_datetime(order_items_df[col])

# %% [markdown]
# Cek apakah data sudah bersih

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# **Cleaning data tabel order_reviews**

# %% [markdown]
# Diawali dengan menghapus kolom yang tidak digunakan dalam proses analisis

# %%
order_reviews_drop_cols=['review_comment_title', 'review_comment_message']
order_reviews_df.drop(order_reviews_drop_cols, axis=1, inplace= True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# Konversikan kolom yang memuat tanggal menjadi Dtype date tima

# %%
order_review_col=['review_creation_date', 'review_answer_timestamp']
for col in order_review_col:
  order_reviews_df[col]=pd.to_datetime(order_reviews_df[col])

# %% [markdown]
# Cek apakah data sudah bersih

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_creation_date     99224 non-null  datetime64[ns]
#  4   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Tahap eksplorasi data yang sudah bersih ini berguna untuk memperoleh insight dan menjawab pertanyaan analisis.

# %% [markdown]
# ### Explore Customers DataFrame

# %% [markdown]
# Pertama akan dilihat dahulu apa saja yang ada di dalam DataFrame customers dengan mengambil 10 sample.

# %%
customers_df.sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 34119  e0bd804d0705c39c21fa5258cbcd7b87  fa6ea9c48be00f2aa18e2647ba7a676b
# 58265  127016e771ff3dea1a8c2c22f09868d8  48808de5f7aae8881946c93b0b522f8b
# 79161  cf82926706d6fb674a9ec6b60677b2f6  94e27bbbd8a0433df936d73d43600471
# 94975  86de6692e6fdfad3c3221414dc73d4a9  1176d8491a0ae7e42bc65b08ddd1d924
# 44230  012b69962ffef2be728865fe6a90359c  86b0aa3acd7e8f7427c8915780f5cd27
# 69801  1a00ab086e473de2fb5ec217d4c6ca0e  d7ef684a4356c48be1e9b1561092bef6
# 61160  a56ca9095e2e7e3dc2d068c86fa81d68  03d01a4b09e221a1bb37343eb990dbda
# 36668  4b1827ec0c64d72de57b69f7213aa307  c991d3a00bf798c9383bfad44226e3ad
# 56700  e7a5a238f60bebe0efe9ccbda1042ed5  15a4554642b5fe5a003bb9a7a2ec4893
# 11229  26d283dae44fbc9eee874cecca589853  013dd47ed31ce4de00cb434b2cae5386
#
#        customer_zip_code_prefix         customer_city customer_state
# 34119                      6408               barueri             SP
# 58265                      4173             sao paulo             SP
# 79161                      9321                  maua             SP
# 94975                      5318             sao paulo             SP
# 44230                     66615                 belem             PA
# 69801                     37130               alfenas             MG
# 61160                      4575             sao paulo             SP
# 36668                     79301               corumba             MS
# 56700                     22050        rio de janeiro             RJ
# 11229                     74920  aparecida de goiania             GO

# %% [markdown]
# Melihat rangkuman parameter statistiknya

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %% [markdown]
# Melihat demografi pelanggan berdasarkan kota(city) tempat pembeli tinggal

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Selanjutnya, akan dilihat demografi pembeli berdasarkan negara bagian(state)

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Dari kedua demografi pembeli di atas, dapat dilihat bahwa pembeli terbanyak berasal dari Kota Sao Paulo dan Negara bagian Sao Paulo (SP). Pembeli paling sedikit terdapat di kota-kota seperti Rios dos Cedros, Laogao, dan lainnya, sedangkan untuk negara bagian dengan pembeli paling sedikit adalah Roraima (RR)

# %% [markdown]
# ### Explore Order Payments DataFrame

# %% [markdown]
# Pertama akan dilihat dahulu apa saja yang ada di dalam DataFrame order payments dengan mengambil 10 sample.

# %%
order_payments_df.sample(10)
# Out:
#                                order_id  payment_sequential payment_type  \
# 19405  ab7645aa9bb508419e3dfcd8805edf76                   1  credit_card
# 92613  5eeef0a291829b4a3e2ebfd8effac242                   1  credit_card
# 46778  777d025bd646af7e0278d6fb3c51a0f3                   1  credit_card
# 71051  cb00b252d2c836eeeb1d73ec439a0849                   1       boleto
# 4934   a7c778535820b8a189eafd6bd2fb3cf0                   1       boleto
# 84906  456cbabc88163cbe54a149c9d51e55d3                   1  credit_card
# 8110   c634e50ec075d06b4cd1d70527697f08                   1  credit_card
# 33252  41c291a561e0257e25d6a75037e5a6a1                   1  credit_card
# 33276  a41147091da0a907ca54accc4bf5b231                   1  credit_card
# 87962  cb1f639d88a5c4d9049c6c61d563f5b8                   1  credit_card
#
#        payment_installments  payment_value
# 19405                     1         201.65
# 92613                     3          65.73
# 46778                     3         213.60
# 71051                     1        1442.15
# 4934                      1          46.13
# 84906                     1          35.40
# 8110                      8         134.32
# 33252                     1          52.50
# 33276                     8         719.65
# 87962                    10         275.63

# %% [markdown]
# Rangkum parameter statistiknya

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# count          103886.000000  103886.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                2.853349     154.100380
# std                 2.687051     217.494064
# min                 0.000000       0.000000
# 25%                 1.000000      56.790000
# 50%                 1.000000     100.000000
# 75%                 4.000000     171.837500
# max                24.000000   13664.080000

# %% [markdown]
# Berdasarkan data di atas, terdapat rata-rata pengeluaran pembeli dalam satu kali pesanan yaitu sebesar 217.494064.

# %% [markdown]
# Pembeli akan dikelompokkan berdasarkan metode pembayaran yang digunakan

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# Metode pembayaran yang paling banyak dipakai yaitu credit card dan paling jarang digunakan yaitu debit card

# %% [markdown]
# ### Explore Customer dan Orders DataFrame

# %% [markdown]
# Menggabungkan customers_df dengan orders_df

# %%
customer_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customer_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2017-05-16 15:22:12          2017-05-23 10:47:57
# 1 2018-01-12 20:58:32          2018-01-15 17:14:59
# 2 2018-05-20 16:19:10          2018-06-11 14:31:00
# 3 2018-03-13 17:29:19          2018-03-27 23:22:42
# 4 2018-07-29 10:10:09          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-05-25 10:35:35                    2017-06-05
# 1           2018-01-29 12:41:19                    2018-02-06
# 2           2018-06-14 17:58:51                    2018-06-13
# 3           2018-03-28 16:04:25                    2018-04-10
# 4           2018-08-09 20:55:48                    2018-08-15

# %% [markdown]
# Selanjutnya, akan dicek status pada pembeli, status "active" merupakan status untuk pelanggan yang pernah melakukan pembelian minimal sekali, dan status "non active" untuk pelanggan yang belum pernah melakukan pembelian.

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 31504  55a186d87435d0bbc44e79d149fd4d30  575862d1a0824cc9a387286f0553bf5c
# 34752  c495ae8dfa83b158b111fc7b8304f032  55f8517e3e572aa06923169cf5d0b011
# 14800  a9509fd6fbf74f21f49451b41f7a99d0  ee7c8776ca249426d1d17e6d48b622ea
# 27     6e359a57a91f84095cc64e1b351aef8c  2e6a42a9b5cbb0da62988694f18ee295
# 44524  524b931bb2666da2d665da0984cafcb3  a04d29ea1834c0c9ba7030d68a98f6e4
# 70647  28906e836da1302f6be9abbb3738cb92  581b99de2e551ed8dd889935346fde3a
# 29962  89ce2f3bc0e53c9acab6af7e69476505  72f9ad8056c57cf96a7d3b617ec5fde8
# 58838  41cf71109d64452d0b2a886144df4b19  1f508e60fbbe74dbec28e4013599d0ff
# 90107  00af928c0a307dfdb37122943a1e6902  fd45ef982d27eb5aaa153990b7c8140b
# 81444  3143b2da761120eee4352f329a0fc244  3611bfc3365eee7df8d4c5d039afcd86
#
#        customer_zip_code_prefix          customer_city customer_state  status
# 31504                     89990  sao lourenco do oeste             SC  Active
# 34752                     13480                limeira             SP  Active
# 14800                     35240       conselheiro pena             MG  Active
# 27                         4571              sao paulo             SP  Active
# 44524                     36091           juiz de fora             MG  Active
# 70647                     38020                uberaba             MG  Active
# 29962                      4842              sao paulo             SP  Active
# 58838                      9941                diadema             SP  Active
# 90107                     18275                  tatui             SP  Active
# 81444                      4011              sao paulo             SP  Active

# %% [markdown]
# Akan dihitung berapa pembeli yang memiliki status active dan non active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        94496
# Non Active     4945
# Name: customer_id, dtype: int64

# %% [markdown]
# Ternyata terdapat 99441 pembeli yang minimal telah melakukan 1 kali pembelian

# %% [markdown]
# ### Explore Orders dan Order Items DataFrame

# %% [markdown]
# Menggabungkan orders_df dan order_items_df guna mendapatkan informasi yang lebih lengkap tentang setiap pesanan termasuk detail barang yang dipesan.

# %%
orders_orderitems_df = pd.merge(
    left=orders_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_orderitems_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
# 3                    2017-12-15            1.0
# 4                    2018-02-26            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
#
#   shipping_limit_date   price  freight_value
# 0 2017-10-06 11:07:15   29.99           8.72
# 1 2018-07-30 03:24:27  118.70          22.76
# 2 2018-08-13 08:55:23  159.90          19.22
# 3 2017-11-23 19:45:59   45.00          27.20
# 4 2018-02-19 20:31:37   19.90           8.72

# %% [markdown]
# Melihat status pesanan

# %%
orders_orderitems_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      91684
# shipped         1060
# canceled         599
# unavailable      570
# invoiced         293
# processing       283
# created            5
# approved           2
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Orders dan Payments

# %% [markdown]
# Menggabungkan order_df dan order_payments_df berdasarkan order_id

# %%
orders_payments_df = pd.merge(
    left=orders_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_payments_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                 1.0  credit_card
# 1                    2017-10-18                 3.0      voucher
# 2                    2017-10-18                 2.0      voucher
# 3                    2018-08-13                 1.0       boleto
# 4                    2018-09-04                 1.0  credit_card
#
#    payment_installments  payment_value
# 0                   1.0          18.12
# 1                   1.0           2.00
# 2                   1.0          18.59
# 3                   1.0         141.46
# 4                   3.0         179.12

# %% [markdown]
# Akan ditelusuri apakah ada pesanan yang belum dibayar

# %%
orders_payments_df["payment_value"].fillna(0, inplace= True)
unpaid_orders_count = orders_payments_df[orders_payments_df["payment_value"]==0].shape[0]
print(f"Jumlah pesanan yang belum dibayar: {unpaid_orders_count}")
# Out:
# Jumlah pesanan yang belum dibayar: 9

# %% [markdown]
# ### Explore Reviews dan Orders

# %%
orders_reviews_df = pd.merge(
    left=orders_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_reviews_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                         review_id  \
# 0                    2017-10-18  a54f0611adc9ed256b57ede6b6eb5114
# 1                    2018-08-13  8d5266042046a06655c8db133d120ba5
# 2                    2018-09-04  e73b67b67587f7644d5bd1a52deb1b01
# 3                    2017-12-15  359d03e676b3c069f62cadba8dd3f6e8
# 4                    2018-02-26  e50934924e227544ba8246aeb3770dd4
#
#    review_score review_creation_date review_answer_timestamp
# 0           4.0           2017-10-11     2017-10-12 03:43:48
# 1           4.0           2018-08-08     2018-08-08 18:37:50
# 2           5.0           2018-08-18     2018-08-22 19:07:58
# 3           5.0           2017-12-03     2017-12-05 19:21:58
# 4           5.0           2018-02-17     2018-02-18 13:02:51

# %% [markdown]
# ### Explore Products dan Products Category

# %% [markdown]
# Menggabungkan products_df dengan products_category_df

# %%
products = pd.merge(
    left=products_df,
    right=products_category_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares

# %%
products.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3639
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %% [markdown]
# Kategori produk dalam Bahasa Inggris

# %%
products.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3639
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# ### Merge

# %% [markdown]
# Proses penggabungan beberapa DataFrame

# %% [markdown]
# **Merge orders_payments_df & orders_reviews_df berdasarkan order_id**

# %%
payments_reviews = pd.merge(
    left=orders_payments_df,
    right=orders_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
payments_reviews.head()
# Out:
#                            order_id                     customer_id_x  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status_x order_purchase_timestamp_x order_approved_at_x  \
# 0      delivered        2017-10-02 10:56:33 2017-10-02 11:07:15
# 1      delivered        2017-10-02 10:56:33 2017-10-02 11:07:15
# 2      delivered        2017-10-02 10:56:33 2017-10-02 11:07:15
# 3      delivered        2018-07-24 20:41:37 2018-07-26 03:24:27
# 4      delivered        2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date_x order_delivered_customer_date_x  \
# 0            2017-10-04 19:55:00             2017-10-10 21:25:13
# 1            2017-10-04 19:55:00             2017-10-10 21:25:13
# 2            2017-10-04 19:55:00             2017-10-10 21:25:13
# 3            2018-07-26 14:31:00             2018-08-07 15:27:45
# 4            2018-08-08 13:50:00             2018-08-17 18:06:29
#
#   order_estimated_delivery_date_x  payment_sequential payment_type  ...  \
# 0                      2017-10-18                 1.0  credit_card  ...
# 1                      2017-10-18                 3.0      voucher  ...
# 2                      2017-10-18                 2.0      voucher  ...
# 3                      2018-08-13                 1.0       boleto  ...
# 4                      2018-09-04                 1.0  credit_card  ...
#
#    order_status_y  order_purchase_timestamp_y order_approved_at_y  \
# 0       delivered         2017-10-02 10:56:33 2017-10-02 11:07:15
# 1       delivered         2017-10-02 10:56:33 2017-10-02 11:07:15
# 2       delivered         2017-10-02 10:56:33 2017-10-02 11:07:15
# 3       delivered         2018-07-24 20:41:37 2018-07-26 03:24:27
# 4       delivered         2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date_y order_delivered_customer_date_y  \
# 0            2017-10-04 19:55:00             2017-10-10 21:25:13
# 1            2017-10-04 19:55:00             2017-10-10 21:25:13
# 2            2017-10-04 19:55:00             2017-10-10 21:25:13
# 3            2018-07-26 14:31:00             2018-08-07 15:27:45
# 4            2018-08-08 13:50:00             2018-08-17 18:06:29
#
#   order_estimated_delivery_date_y                         review_id  \
# 0                      2017-10-18  a54f0611adc9ed256b57ede6b6eb5114
# 1                      2017-10-18  a54f0611adc9ed256b57ede6b6eb5114
# 2                      2017-10-18  a54f0611adc9ed256b57ede6b6eb5114
# 3                      2018-08-13  8d5266042046a06655c8db133d120ba5
# 4                      2018-09-04  e73b67b67587f7644d5bd1a52deb1b01
#
#   review_score review_creation_date review_answer_timestamp
# 0          4.0           2017-10-11     2017-10-12 03:43:48
# 1          4.0           2017-10-11     2017-10-12 03:43:48
# 2          4.0           2017-10-11     2017-10-12 03:43:48
# 3          4.0           2018-08-08     2018-08-08 18:37:50
# 4          5.0           2018-08-18     2018-08-22 19:07:58
#
# [5 rows x 23 columns]

# %% [markdown]
# **Merge customer_orders_df & payments_reviews berdasarkan order_id**

# %%
customers = pd.merge(
    left=customer_orders_df,
    right=payments_reviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at order_delivered_carrier_date  ... order_status_y  \
# 0 2017-05-16 15:22:12          2017-05-23 10:47:57  ...      delivered
# 1 2018-01-12 20:58:32          2018-01-15 17:14:59  ...      delivered
# 2 2018-05-20 16:19:10          2018-06-11 14:31:00  ...      delivered
# 3 2018-03-13 17:29:19          2018-03-27 23:22:42  ...      delivered
# 4 2018-07-29 10:10:09          2018-07-30 15:16:00  ...      delivered
#
#   order_purchase_timestamp_y order_approved_at_y  \
# 0        2017-05-16 15:05:35 2017-05-16 15:22:12
# 1        2018-01-12 20:48:24 2018-01-12 20:58:32
# 2        2018-05-19 16:07:45 2018-05-20 16:19:10
# 3        2018-03-13 16:06:38 2018-03-13 17:29:19
# 4        2018-07-29 09:51:30 2018-07-29 10:10:09
#
#   order_delivered_carrier_date_y order_delivered_customer_date_y  \
# 0            2017-05-23 10:47:57             2017-05-25 10:35:35
# 1            2018-01-15 17:14:59             2018-01-29 12:41:19
# 2            2018-06-11 14:31:00             2018-06-14 17:58:51
# 3            2018-03-27 23:22:42             2018-03-28 16:04:25
# 4            2018-07-30 15:16:00             2018-08-09 20:55:48
#
#   order_estimated_delivery_date_y                         review_id  \
# 0                      2017-06-05  88b8b52d46df026a9d1ad2136a59b30b
# 1                      2018-02-06  02fc48a9efa3e3d0f1a8ea26507eeec3
# 2                      2018-06-13  5ad6695d76ee186dc473c42706984d87
# 3                      2018-04-10  059a801bb31f6aab2266e672cab87bc5
# 4                      2018-08-15  8490879d58d6c5d7773f2739a03f089a
#
#   review_score review_creation_date  review_answer_timestamp
# 0          4.0           2017-05-26      2017-05-30 22:34:40
# 1          5.0           2018-01-30      2018-02-10 22:43:29
# 2          5.0           2018-06-15      2018-06-15 12:10:59
# 3          5.0           2018-03-29      2018-04-02 18:36:47
# 4          5.0           2018-08-10      2018-08-17 01:59:52
#
# [5 rows x 34 columns]

# %% [markdown]
# **Merge order_orderitems_df & products berdasarkan product_id**

# %%
orders = pd.merge(
    left=orders_orderitems_df,
    right=products,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
# 3                    2017-12-15            1.0
# 4                    2018-02-26            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
#
#   shipping_limit_date   price  freight_value  product_category_name  \
# 0 2017-10-06 11:07:15   29.99           8.72  utilidades_domesticas
# 1 2018-07-30 03:24:27  118.70          22.76             perfumaria
# 2 2018-08-13 08:55:23  159.90          19.22             automotivo
# 3 2017-11-23 19:45:59   45.00          27.20               pet_shop
# 4 2018-02-19 20:31:37   19.90           8.72              papelaria
#
#    product_photos_qty product_category_name_english
# 0                 4.0                    housewares
# 1                 1.0                     perfumery
# 2                 1.0                          auto
# 3                 3.0                      pet_shop
# 4                 4.0                    stationery

# %% [markdown]
# ### Explore All Data

# %% [markdown]
# Pertama, merge semua datanya kecuali geolocation dataset karena informasinya yang dibutuhkan sudah diwakilkan di customers_df .Hal ini dilakukan untuk melihat pola pembelian berdasarkan demografi pelanggan yang mampu menampung semua informasi tabel

# %%
all_data = pd.merge(
    left=customers,
    right=orders,
    how="left",
    left_on="order_id",
    right_on="order_id",
    suffixes=("_customers","_orders")
)
all_data.head()
# Out:
#               customer_id_customers                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status_customers  \
# 0  00e7ee1b050b8499577073aeb2a297a1              delivered
# 1  29150127e6685892b6eab3eec79f59c7              delivered
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2              delivered
# 3  951670f92359f4fe4a63112aa7306eba              delivered
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f              delivered
#
#   order_purchase_timestamp_customers order_approved_at_customers  \
# 0                2017-05-16 15:05:35         2017-05-16 15:22:12
# 1                2018-01-12 20:48:24         2018-01-12 20:58:32
# 2                2018-05-19 16:07:45         2018-05-20 16:19:10
# 3                2018-03-13 16:06:38         2018-03-13 17:29:19
# 4                2018-07-29 09:51:30         2018-07-29 10:10:09
#
#   order_delivered_carrier_date_customers  ...  \
# 0                    2017-05-23 10:47:57  ...
# 1                    2018-01-15 17:14:59  ...
# 2                    2018-06-11 14:31:00  ...
# 3                    2018-03-27 23:22:42  ...
# 4                    2018-07-30 15:16:00  ...
#
#   order_estimated_delivery_date_orders order_item_id  \
# 0                           2017-06-05           1.0
# 1                           2018-02-06           1.0
# 2                           2018-06-13           1.0
# 3                           2018-04-10           1.0
# 4                           2018-08-15           1.0
#
#                          product_id                         seller_id  \
# 0  a9516a079e37a9c9c36b9b78b10169e8  7c67e1448b00f6e969d365cea6b010ab
# 1  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 2  bd07b66896d6f1494f5b86251848ced7  7c67e1448b00f6e969d365cea6b010ab
# 3  a5647c44af977b148e0a3a4751a09e2e  7c67e1448b00f6e969d365cea6b010ab
# 4  9391a573abe00141c56e38d84d7d5b3b  4a3ca9315b744ce9f8e9374361493884
#
#   shipping_limit_date   price freight_value  product_category_name  \
# 0 2017-05-22 15:22:12  124.99         21.88      moveis_escritorio
# 1 2018-01-18 20:58:32  289.00         46.48  utilidades_domesticas
# 2 2018-06-05 16:19:10  139.94         17.79      moveis_escritorio
# 3 2018-03-27 16:31:16  149.94         23.36      moveis_escritorio
# 4 2018-07-31 10:10:09  230.00         22.25          casa_conforto
#
#   product_photos_qty  product_category_name_english
# 0                1.0               office_furniture
# 1                3.0                     housewares
# 2                1.0               office_furniture
# 3                1.0               office_furniture
# 4                1.0                   home_confort
#
# [5 rows x 50 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118112 entries, 0 to 118111
# Data columns (total 50 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   customer_id_customers                    118112 non-null  object
#  1   customer_unique_id                       118112 non-null  object
#  2   customer_zip_code_prefix                 118112 non-null  int64
#  3   customer_city                            118112 non-null  object
#  4   customer_state                           118112 non-null  object
#  5   order_id                                 113167 non-null  object
#  6   order_status_customers                   113167 non-null  object
#  7   order_purchase_timestamp_customers       113167 non-null  datetime64[ns]
#  8   order_approved_at_customers              113001 non-null  datetime64[ns]
#  9   order_delivered_carrier_date_customers   111196 non-null  datetime64[ns]
#  10  order_delivered_customer_date_customers  109919 non-null  datetime64[ns]
#  11  order_estimated_delivery_date_customers  113166 non-null  datetime64[ns]
#  12  customer_id_x                            113167 non-null  object
#  13  order_status_x                           113167 non-null  object
#  14  order_purchase_timestamp_x               113167 non-null  datetime64[ns]
#  15  order_approved_at_x                      113001 non-null  datetime64[ns]
#  16  order_delivered_carrier_date_x           111196 non-null  datetime64[ns]
#  17  order_delivered_customer_date_x          109919 non-null  datetime64[ns]
#  18  order_estimated_delivery_date_x          113166 non-null  datetime64[ns]
#  19  payment_sequential                       113164 non-null  float64
#  20  payment_type                             113164 non-null  object
#  21  payment_installments                     113164 non-null  float64
#  22  payment_value                            113167 non-null  float64
#  23  customer_id_y                            113167 non-null  object
#  24  order_status_y                           113167 non-null  object
#  25  order_purchase_timestamp_y               113167 non-null  datetime64[ns]
#  26  order_approved_at_y                      113001 non-null  datetime64[ns]
#  27  order_delivered_carrier_date_y           111196 non-null  datetime64[ns]
#  28  order_delivered_customer_date_y          109919 non-null  datetime64[ns]
#  29  order_estimated_delivery_date_y          113166 non-null  datetime64[ns]
#  30  review_id                                112236 non-null  object
#  31  review_score                             112236 non-null  float64
#  32  review_creation_date                     112236 non-null  datetime64[ns]
#  33  review_answer_timestamp                  112236 non-null  datetime64[ns]
#  34  customer_id_orders                       113167 non-null  object
#  35  order_status_orders                      113167 non-null  object
#  36  order_purchase_timestamp_orders          113167 non-null  datetime64[ns]
#  37  order_approved_at_orders                 113001 non-null  datetime64[ns]
#  38  order_delivered_carrier_date_orders      111196 non-null  datetime64[ns]
#  39  order_delivered_customer_date_orders     109919 non-null  datetime64[ns]
#  40  order_estimated_delivery_date_orders     113166 non-null  datetime64[ns]
#  41  order_item_id                            112386 non-null  float64
#  42  product_id                               112386 non-null  object
#  43  seller_id                                112386 non-null  object
#  44  shipping_limit_date                      112386 non-null  datetime64[ns]
#  45  price                                    112386 non-null  float64
#  46  freight_value                            112386 non-null  float64
#  47  product_category_name                    112386 non-null  object
#  48  product_photos_qty                       112386 non-null  float64
#  49  product_category_name_english            112363 non-null  object
# dtypes: datetime64[ns](23), float64(8), int64(1), object(18)
# memory usage: 45.1+ MB

# %% [markdown]
# Akan dilihat preferensi pembelian berdasarkan state dan kategori produk.

# %%
all_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  634.60         217.95
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 4803.69        1214.44
#                stationery                      276.80          73.80
#                telephony                       844.26         499.80
#                toys                           1584.16         401.37
#                watches_gifts                  4384.22         843.71
#
# [1339 rows x 2 columns]

# %% [markdown]
# Akan dilihat preferensi pembeli berdasarkan kota dan kategori produk

# %%
all_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
#                     bed_bath_table                 142.80          31.36
# ...                                                   ...            ...
# ze doca             garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              bed_bath_table                  29.90          16.79
#                     computers_accessories           69.90          20.98
#
# [24530 rows x 2 columns]

# %% [markdown]
# Akan dilihat preferensi pembeli berdasarkan state dan metode pembayaran yang digunakan

# %%
all_data.groupby("customer_state").agg({
    "payment_type": lambda x: ', '.join(x.dropna().astype(str).unique()),
    "payment_value": "sum"
}).reset_index()
# Out:
#    customer_state                                       payment_type  \
# 0              AC           credit_card, boleto, voucher, debit_card
# 1              AL           boleto, credit_card, debit_card, voucher
# 2              AM           credit_card, boleto, voucher, debit_card
# 3              AP                       credit_card, boleto, voucher
# 4              BA           credit_card, boleto, voucher, debit_card
# 5              CE           credit_card, voucher, boleto, debit_card
# 6              DF           boleto, credit_card, voucher, debit_card
# 7              ES           credit_card, boleto, voucher, debit_card
# 8              GO           credit_card, boleto, voucher, debit_card
# 9              MA           credit_card, boleto, voucher, debit_card
# 10             MG           credit_card, boleto, voucher, debit_card
# 11             MS           credit_card, voucher, boleto, debit_card
# 12             MT           credit_card, boleto, voucher, debit_card
# 13             PA           credit_card, voucher, boleto, debit_card
# 14             PB           credit_card, boleto, debit_card, voucher
# 15             PE           credit_card, debit_card, boleto, voucher
# 16             PI           boleto, credit_card, voucher, debit_card
# 17             PR           debit_card, credit_card, voucher, boleto
# 18             RJ           credit_card, debit_card, voucher, boleto
# 19             RN           credit_card, boleto, voucher, debit_card
# 20             RO           credit_card, boleto, voucher, debit_card
# 21             RR                                boleto, credit_card
# 22             RS           credit_card, boleto, voucher, debit_card
# 23             SC           debit_card, credit_card, boleto, voucher
# 24             SE           credit_card, boleto, voucher, debit_card
# 25             SP  credit_card, voucher, boleto, debit_card, not_...
# 26             TO           credit_card, boleto, debit_card, voucher
#
#     payment_value
# 0        24665.05
# 1       106081.39
# 2        28271.78
# 3        20859.14
# 4       758462.87
# 5       338596.46
# 6       420953.11
# 7       383994.43
# 8       504757.92
# 9       190797.01
# 10     2235114.25
# 11      159062.12
# 12      246614.42
# 13      252246.01
# 14      169881.08
# 15      360009.12
# 16      134397.12
# 17     1032201.26
# 18     2657925.01
# 19      111742.52
# 20       63016.95
# 21       12173.60
# 22     1112970.21
# 23      758468.85
# 24       85568.93
# 25     7289970.39
# 26       65495.22

# %% [markdown]
# Melihat bagaimana review yang diberikan untuk setiap kategori produk.

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         175          1.0  5.0
# air_conditioning                   242          1.0  5.0
# art                                193          1.0  5.0
# arts_and_craftmanship               22          1.0  5.0
# audio                              331          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2196          1.0  5.0
# tablets_printing_image              77          1.0  5.0
# telephony                         3984          1.0  5.0
# toys                              3696          1.0  5.0
# watches_gifts                     5322          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# **Convert all_data to .csv**

# %%
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk mana yang terjual paling banyak dan paling sedikit?

# %% [markdown]
# Untung menghitung banyaknya produk, pertama akan dilakukan grouping berdasarkan kategori produk Bahasa Inggris, lalu dihitung menggunakan count(), dan diurutkan dari jumlah penjualan produk yang paling tinggi.

# %%
sum_order_items_df = all_data.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items_df = sum_order_items_df.rename(columns={"product_id": "products", "product_category_name_english":"category"})
sum_order_items_df = sum_order_items_df.sort_values(by="products", ascending=False)

sum_order_items_df.head()
# Out:
#                  category  products
# 7          bed_bath_table     12960
# 43          health_beauty      9541
# 65         sports_leisure      8583
# 39        furniture_decor      8366
# 15  computers_accessories      7719

# %% [markdown]
# Selanjutnya jika diurutkan dari jumlah penjualan produk paling rendah/paling sedikit

# %%
sum_order_items_df.sort_values(by="products", ascending=True).head(5)
# Out:
#                      category  products
# 61      security_and_services         2
# 29  fashion_childrens_clothes         8
# 52                 la_cuisine        13
# 11          cds_dvds_musicals        14
# 3       arts_and_craftmanship        23

# %% [markdown]
# **Visualisasi menggunakan bar chart**

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors_best = ["#00FF57", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
colors_least = ["#F90611", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]


sns.barplot(x="products", y="category", data=sum_order_items_df.sort_values(by="products", ascending=False).head(5), palette=colors_best, hue="category", legend=False, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best-Selling Products", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="products", y="category", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors_least, hue="category", legend=False, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Least-Selling Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best-Selling and Least-Selling Product", fontsize=20)
plt.show()

# %% [markdown]
# Berdasarkan bar chart di atas, dapat dilihat bahwa kategori produk **bed_bath_table** menjadi produk yang paling banyak terjual ditandai oleh bar warna hijau sedangkan untuk kategori produk **security_and_services** menjadi produk yang paling sedikit terjual ditandai oleh bar warna merah.

# %% [markdown]
# ### Pertanyaan 2: Dari segi lokasi geografis, wilayah mana yang melakukan pembelian terbanyak?

# %% [markdown]
# Untuk pertanyaan ini, akan dikelompokkan terlebih dahulu berdasarkan state/negara bagiannya

# %%
bystate_df = all_data.groupby(by="customer_state")["customer_id_customers"].nunique().reset_index()
bystate_df.rename(columns={"customer_id_customers": "customer_count"}, inplace=True)
print(bystate_df)
# Out:
#    customer_state  customer_count
# 0              AC              81
# 1              AL             413
# 2              AM             148
# 3              AP              68
# 4              BA            3380
# 5              CE            1336
# 6              DF            2140
# 7              ES            2033
# 8              GO            2020
# 9              MA             747
# 10             MG           11635
# 11             MS             715
# 12             MT             907
# 13             PA             975
# 14             PB             536
# 15             PE            1652
# 16             PI             495
# 17             PR            5045
# 18             RJ           12852
# 19             RN             485
# 20             RO             253
# 21             RR              46
# 22             RS            5466
# 23             SC            3637
# 24             SE             350
# 25             SP           41746
# 26             TO             280

# %% [markdown]
# **Visualisasi menggunakan bar chart**

# %%
plt.figure(figsize=(10, 5))
colors1= ["#8EACCD", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3","#D3D3D3"]
sns.barplot(x="customer_count", y="customer_state", data=bystate_df.sort_values(by="customer_count", ascending=False).head(10), palette=colors1, hue="customer_state", legend=False)

plt.title("Number of Customers by States", loc="center", fontsize=15)
plt.ylabel("State")
plt.xlabel("Number of Customers")
plt.tick_params(axis='y', labelsize=12)

plt.show()

# %% [markdown]
# Selanjutnya dikelompokkan berdasarkan kota

# %%
bycity_df = all_data.groupby(by="customer_city")["customer_id_customers"].nunique().reset_index()
bycity_df.rename(columns={"customer_id_customers": "customer_count"}, inplace=True)
print(bycity_df)
# Out:
#             customer_city  customer_count
# 0     abadia dos dourados               3
# 1               abadiania               1
# 2                  abaete              12
# 3              abaetetuba              11
# 4                 abaiara               2
# ...                   ...             ...
# 4114             xinguara               9
# 4115          xique-xique               3
# 4116             zacarias               2
# 4117              ze doca               5
# 4118               zortea               2
#
# [4119 rows x 2 columns]

# %% [markdown]
# **Visualisasi menggunakan bar plot**

# %%
plt.figure(figsize=(10, 5))
colors1= ["#6A9C89", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3","#D3D3D3"]
sns.barplot(x="customer_count", y="customer_city", data=bycity_df.sort_values(by="customer_count", ascending=False).head(10), palette=colors1, hue="customer_city", legend=False)

plt.title("Number of Customers by City", loc="center", fontsize=15)
plt.ylabel("City")
plt.xlabel("Number of Customers")
plt.tick_params(axis='y', labelsize=12)

plt.show()

# %% [markdown]
# Berdasarkan bar chart di atas, dapat dilihat bahwa daerah yang melakukan paling banyak pembelian ada di negara bagian Sao Paulo (SP) dan di Kota Sao Paulo.

# %% [markdown]
# ### Pertanyaan 3: Jenis metode pembayaran apa yang paling umum digunakan oleh customer?

# %% [markdown]
# Berikut adalah metode pembayaran yang paling sering digunakan di seluruh daerah demografis customer

# %%
payment_counts = all_data['payment_type'].value_counts().reset_index()
payment_counts.columns = ['payment_type', 'count']

# %% [markdown]
# **Visualisasi menggunakan bar chart**

# %%
plt.figure(figsize=(10, 6))
colors2= ["#16423C", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3"]
sns.barplot(x='payment_type', y='count', data=payment_counts, palette=colors2, hue="payment_type", legend=False)
plt.title('Most Used Payment Types by Customers', fontsize=16)
plt.xlabel('Number of Transactions', fontsize=14)
plt.ylabel('Payment Type', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Dapat dilihat dari bar chart di atas, dari seluruh daerah demografis customer credit card adalah metode pembayaran yang paling sering digunakan dan memiliki perbedaan yang jauh dengan metode pembayaran lainnya.

# %% [markdown]
# State dengan pembeli terbanyak adalah Sao Paulo. Berikut adalah metode pembayaran yang paling sering digunakan di Sao Paulo yang divisualisasi menggunakan bar chart

# %%
state_payments = "SP"
filtered_data = all_data[all_data['customer_state'] == state_payments]

# %%
payment_counts = filtered_data['payment_type'].value_counts().reset_index()
payment_counts.columns = ['payment_type', 'count']

# %%
plt.figure(figsize=(10, 6))
colors2= ["#16423C", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3"]
sns.barplot(x='payment_type', y='count', data=payment_counts, palette=colors2, hue="payment_type", legend=False)
plt.title(f'Most Used Payment Types in Sao Paulo', fontsize=16)
plt.xlabel('Number of Transactions', fontsize=14)
plt.ylabel('Payment Type', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Sama dengan di daerah demografis keseluruhan, Sao Paulo juga memiliki metode pembayaran yang paling menonjol yaitu credit card dan bar chart yang dihasilkan cukup menyerupai bar chart keseluruhan.

# %% [markdown]
# ### Pertanyaan 4: Berdasarkan umpan balik yang diterima, bagaimana tingkat kepuasan customer terhadap layanan yang diberikan?

# %% [markdown]
# Berdasarkan review score yang diberikan oleh pelanggan dari 1 hingga 5 dimana 5 menggambarkan customer sangat puas dengan pelayanan yang diberikan dan 1 menggambarkan bahwa customer sangat tidak puas dengan pelayanan yang diberikan. Dapat dilihat rangkumannya terlebih dahulu.

# %%
rating_summary = all_data['review_score'].value_counts().sort_index()
print("Rangkuman Review Score:")
for rating, count in rating_summary.items():
    print(f"Score {rating}: {count} ulasan")
# Out:
# Rangkuman Review Score:
# Score 1.0: 14705 ulasan
# Score 2.0: 3944 ulasan
# Score 3.0: 9385 ulasan
# Score 4.0: 21196 ulasan
# Score 5.0: 63006 ulasan

# %% [markdown]
# **Visualisasi menggunakan bar chart**

# %%
plt.figure(figsize=(8, 6))
colors3= ["#B8001F", "#D3D3D3", "#D3D3D3", "#D3D3D3","#347928"]
sns.countplot(x='review_score', data=all_data, palette=colors3)

plt.title('Customer Satisfaction Review', fontsize=16)
plt.xlabel('Satisfaction Rating (1 to 5)', fontsize=14)
plt.ylabel('Number of Customers', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
# Out:
# <ipython-input-119-a2a5c0146d37>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='review_score', data=all_data, palette=colors3)

# %% [markdown]
# Dapat dilihat pada bar chart tersebut bahwa customer paling banyak memberikan review score bernilai 5, namun cukup banyak juga yang memberi review score bernilai 1 dibandingkan dengan score 2 dan 3.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Pertanyaan 1: Produk mana yang terjual paling banyak dan paling sedikit?**

# %% [markdown]
# Kategori produk yang paling banyak dibeli adalah bed_bath_table dengan total pembelian sebesar 13697 barang dan kategori produk yang paling sedikit dibeli adalah security_and_services dengan total produk 2 barang.Dari data tersebut, terlihat ketimpangan yang sangat jauh antara produk yang paling banyak dibeli dan yang paling sedikit.

# %% [markdown]
# **Pertanyaan 2: Dari segi lokasi geografis, wilayah mana yang melakukan pembelian terbanyak?**

# %% [markdown]
# Berdasarkan explorasi dan visualisasi, daerah yang paling banyak membeli barang dari E-commerce adalah Sao Paulo State (SP) dan untuk kota yaitu Kota Sao Paulo. Perbedaan jumlah pembeli pada Sao Paulo cenderung jauh dibandingkan dengan negara bagian dan kota lainnya.

# %% [markdown]
# **Pertanyaan 3:Jenis metode pembayaran apa yang paling umum digunakan oleh customer?**

# %% [markdown]
# Beberapa metode pembayaran yaitu ada credit card, boleto, voucher, debit card, dan ada beberapa yang tidak terdeteksi. Dari metode-metode tersebut terdapat metode yang paling sering digunakan yaitu credit card baik di seluruh daerah demografis customer maupun di daerah pembeli terbanyak yaitu Negara bagian Sao Paulo.

# %% [markdown]
# **Pertanyaan 4: Berdasarkan umpan balik yang diterima, bagaimana tingkat kepuasan customer terhadap layanan yang diberikan?**

# %% [markdown]
# Pada bagian review, customer cenderung memberikan review score tertinggi yaitu 5 yang menggambarkan pembeli sangat puas dengan pelayanan yang diberikan, namun harus tetap meningkatkan kembali pelayanan karena tidak sedikit pula customer yang memberikan review score 1 yang menggambarkan customer sangat tidak puas dengan pelayanan yang diberikan.
